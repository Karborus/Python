# %% [markdown]
# ## Question #1 Course Information
# #### Write a program that creates a dictionary containing course numbers and the room numbers of the rooms where the courses meet. The dictionary should have the following keyvalue pairs:
# ![image.png](attachment:image.png)
#
# #### The program should also create a dictionary containing course numbers and the names of the instructors that teach each course. The dictionary should have the following key-value pairs:
# ![image-2.png](attachment:image-2.png)
#
# #### The program should also create a dictionary containing course numbers and the meeting times of each course. The dictionary should have the following key-value pairs:
# ![image-3.png](attachment:image-3.png)

# %%
#set dictionary
rooms={}
rooms.update({'CS101':3004})
rooms.update({'CS102':4501})
rooms.update({'CS103':6755})
rooms.update({'NT110':1244})
rooms.update({'CM241':1411})

#set dictionary
instructors={}
instructors.update({'CS101':'Haynes'})
instructors.update({'CS102':'Alvarado'})
instructors.update({'CS103':'Rich'})
instructors.update({'NT110':'Burke'})
instructors.update({'CM241':'Lee'})

#set dictionary
time={}
time.update({'CS101':'8:00 AM'})
time.update({'CS102':'9:00 AM'})
time.update({'CS103':'10:00 AM'})
time.update({'NT110':'11:00 AM'})
time.update({'CM241':'1:00 PM'})

def main():
    while True:
        n = input('Do you want to continue (y/n): ')
        if(n =='n'):
            break
        else:
            course = input('Enter a course number: ')
            try:
                print()
                print('Room Number: ', rooms[course])
                print('Instructor: ', instructors[course])
                print('Meeting Time: ', time[course])
            except KeyError:
                print('Invalid')
main()
# Out:
# Do you want to continue (y/n):
# Enter a course number: NT110
#
# Room Number:  1244
# Instructor:  Burke
# Meeting Time:  11:00 AM
# Do you want to continue (y/n): y
# Enter a course number: NT222
#
# Invalid
